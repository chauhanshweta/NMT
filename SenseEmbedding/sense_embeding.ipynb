# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ~ && cd -
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-21-4d60409fb6d9>", line 1, in <module>
#     get_ipython().magic('cd ~ && cd -')
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-84>", line 2, in cd
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
cd /content/drive/MyDrive/project_codes/sense_embedding
# Out:
# /content/drive/MyDrive/project_codes/sense_embedding

# %%
# !git clone --recursive https://github.com/tudarmstadt-lt/sensegram.git
# Out:
# Cloning into 'sensegram'...
# remote: Enumerating objects: 1580, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 1580 (delta 0), reused 1 (delta 0), pack-reused 1578
# Receiving objects: 100% (1580/1580), 90.37 MiB | 11.60 MiB/s, done.
# Resolving deltas: 100% (848/848), done.

# %%
cd sensegram/
# Out:
# /content/drive/My Drive/project_codes/sense_embedding/sensegram

# %%
# !pip3 install -r /content/drive/MyDrive/project_codes/sense_embedding/sensegram/requirements.txt
# Out:
# ...
#   Created wheel for clint: filename=clint-0.5.1-py3-none-any.whl size=34474 sha256=1e55ae20d3206960520823750f3f650f56fcbc10d383ae090b3a3b84378c21a5
#   Stored in directory: /root/.cache/pip/wheels/29/97/84/72d17bd67a52abe83c647807c3d77dc4d7c1d7709d7077a5f3
# ...
#   Created wheel for stop-words: filename=stop_words-2018.7.23-py3-none-any.whl size=32912 sha256=c6520c14250709a959ccd3f05dd25160ea94f9efdfd6bd33f42404bfa0fbd5ff
#   Stored in directory: /root/.cache/pip/wheels/fb/86/b2/277b10b1ce9f73ce15059bf6975d4547cc4ec3feeb651978e9
# ...
#   Created wheel for args: filename=args-0.1.0-py3-none-any.whl size=3317 sha256=ae9c4a87697fede931f84aa57776a8c86a571c814fbf82b90124faf904a42f5f
#   Stored in directory: /root/.cache/pip/wheels/6c/9c/cb/445bf22cb64c8cf6a84de63d48ba885470cdf08e77416b6e7a
# Successfully built clint stop-words args
# ...

# %%
# !export PYTHONPATH="/content/drive/MyDrive/project_codes/sense_embedding/sensegram:$PYTHONPATH"

# %%
# !pwd
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# pwd: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
import torch
# !pip install faiss-gpu

# %%
# !pwd
# Out:
# /content/drive/My Drive/project_codes/sense_embedding/sensegram

# %%
# !python train.py /content/drive/MyDrive/project_codes/NLP/Master_Dataset/Hindi/eng_40000.txt
# Out:
# Loading spacy model...
# 2021-11-26 09:05:29,644 : INFO : Loading faiss with AVX2 support.
# 2021-11-26 09:05:29,644 : INFO : Could not load library with AVX2 support due to:
# ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
# 2021-11-26 09:05:29,644 : INFO : Loading faiss.
# 2021-11-26 09:05:29,666 : INFO : Successfully loaded faiss.
# Training word vectors: /content/drive/MyDrive/project_codes/NLP/Master_Dataset/Hindi/eng_40000.txt
# 2021-11-26 09:05:29,673 : INFO : collecting all words and their counts
# Reading from file: /content/drive/MyDrive/project_codes/NLP/Master_Dataset/Hindi/eng_40000.txt
# 2021-11-26 09:05:30,356 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-11-26 09:05:30,511 : INFO : PROGRESS: at sentence #10000, processed 71779 words, keeping 10819 word types
# 2021-11-26 09:05:30,650 : INFO : PROGRESS: at sentence #20000, processed 143784 words, keeping 16706 word types
# ...
