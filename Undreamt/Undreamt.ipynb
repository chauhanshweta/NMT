# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/project_codes/undreamt
# Out:
# /content/drive/MyDrive/project_codes/undreamt

# %%
# !git clone https://github.com/artetxem/undreamt.git
# Out:
# fatal: destination path 'undreamt' already exists and is not an empty directory.

# %%
cd undreamt/
# Out:
# /content/drive/MyDrive/project_codes/undreamt/undreamt

# %%
# !pwd
# %cd ../../..
# Out:
# /content/drive/My Drive/project_codes/undreamt/undreamt
# /content/drive/My Drive

# %%
# %cd project_codes
# Out:
# [Errno 2] No such file or directory: 'project_codes'
# /content/drive/MyDrive/project_codes/undreamt/undreamt

# %%
# !pip3 install torch torchvision

# %%
# !python3 train.py --src /content/drive/MyDrive/project_codes/NLP/Master_Dataset/Hindi/hi_40000.txt --trg /content/drive/MyDrive/project_codes/NLP/Master_Dataset/Hindi/eng_40000.txt --src_embeddings /content/drive/MyDrive/project_codes/vecmap_output/hindimapped300 --trg_embeddings /content/drive/MyDrive/project_codes/vecmap_output/english_mapped_300 --save MODEL_PREFIX --save_interval 1000 --cuda
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /content/drive/My Drive/project_codes/undreamt/undreamt/undreamt/translator.py:59: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   varids = self.device(Variable(torch.LongTensor(ids), requires_grad=False, volatile=not train))
# /content/drive/My Drive/project_codes/undreamt/undreamt/undreamt/attention.py:45: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/Indexing.cu:963.)
#   align.data.masked_fill_(mask, -float('inf'))
#
# STEP 1000 x 50
# Source to target (backtranslation)
#   - Training:       179.80   (176.71s: 4806.28tok/s src, 3305.02tok/s trg; epoch 26)
# ...

# %%
# !python3 train.py --help

# %% [markdown]
# sense emb bt

# %%
# !python3 train.py --src /content/drive/MyDrive/Datasets/ENG-HIN/en_cln_sense --trg /content/drive/MyDrive/Datasets/ENG-HIN/WMT_IMDB_IITB/cle_train.hi --src_embeddings /content/drive/MyDrive/WSD/english_sense_mapped_sup --trg_embeddings /content/drive/MyDrive/WSD/hindi_sense_mapped_sup --save en-hi-senseBT --save_interval 5000 --cuda

# %%
# !python3 train.py --src /content/drive/MyDrive/Datasets/ENG-HIN/en_cln_sense --trg /content/drive/MyDrive/Datasets/ENG-HIN/WMT_IMDB_IITB/cle_train.hi --src2trg /content/drive/MyDrive/Datasets/ENG-HIN/WMT/train.en /content/drive/MyDrive/Datasets/ENG-HIN/WMT/cle_train.hi --src_embeddings /content/drive/MyDrive/WSD/english_sense_mapped_sup --trg_embeddings /content/drive/MyDrive/WSD/hindi_sense_mapped_sup --save en-hi-senseBT --save_interval 5000 --cuda

# %%
# !python3 train.py /content/drive/MyDrive/Datasets/ENG-HIN/en_cln_sense(sm)_parallel

# %% [markdown]
# mm

# %%
# !python3 train.py --src /content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/HINDI_mono_cl_pn.txt --trg /content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/KANGARI_mono_cl_pn.txt --src_embeddings /content/drive/My\ Drive/Embeddings/HIN-KAN/VECMAP/semi-supervised/HINDI_vecmap_300D --trg_embeddings /content/drive/My\ Drive/Embeddings/HIN-KAN/VECMAP/semi-supervised/KANGARI_vecmap_300D --save MODEL_PREFIX --save_interval 1 --cuda

# %%
# !python3 train.py --src2trg /content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/HINDI_parallel_cl_pn.txt /content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/KANGARI_parallel_cl_pn.txt  --src_embeddings /content/drive/My\ Drive/Embeddings/HIN-KAN/VECMAP/semi-supervised/HINDI_vecmap_300D --trg_embeddings /content/drive/My\ Drive/Embeddings/HIN-KAN/VECMAP/semi-supervised/KANGARI_vecmap_300D --embedding_size 300 --learn_encoder_embeddings --disable_denoising --save MODEL_PREFIX --cuda --save_interval 10000

# %% [markdown]
# bpe

# %%
# !sed -r 's/(@@ )|(@@ ?$)/_ /g'  /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/KANGARI_mono_cl_pn.txtBPE > /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/KANGARI2_mono_cl_pn.txtBPE

# %%
# !python3 train.py --src /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/HINDI_mono_cl_pn.txtBPE --trg /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/KANGARI_mono_cl_pn.txtBPE --src_embeddings /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/HINDI_mono_fastT_subw.hi.vec --trg_embeddings /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/KANGARI_mono_fastT_subw.hi.vec --src_vocabulary /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/HIN_mono_cl_pn-jointvocab --trg_vocabulary /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/KAN_mono_cl_pn-jointvocab --save /content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/model/jbpe_un50k --save_interval 100 --cuda
# Out:
# Traceback (most recent call last):
#   File "train.py", line 20, in <module>
#     undreamt.train.main_train()
#   File "/content/drive/My Drive/project_codes/undreamt/undreamt/undreamt/train.py", line 127, in main_train
#     f = open(args.src_vocabulary, encoding=args.encoding, errors='surrogateescape')
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Datasets/HIN-KAN/cleaned/joint-BPE/50000/HIN_mono_cl_pn-jointvocab'

# %%
 # !pwd
 #models
 #0:
 # /content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/Models/old/MODEL_PREFIX.final.src2trg.pth
 #1:
 #semi2
 # /content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/Models/Semi1/Ayush_semi1.final.src2trg.pth
 #2:
 # unsupervised
 # /content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/4_Aug_2020/MODEL_PREFIX.final.src2trg.pth
 #supervised
 #/content/drive/My\ Drive/UNdreaMT/undreamt/MODEL_PREFIX.it90000.src2trg.pth
 #3:
 # semi 1
 # /content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/4_Aug_2020/Semi1.final.src2trg.pth

 #test set2
 #/content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/test_set2/Hin_test.txt

 #--beam_size 12
# Out:
# /content/drive/My Drive/UNdreaMT/undreamt

# %%
undreamt source to target translation

# %%
# !python3 translate.py /content/drive/MyDrive/project_codes/undreamt/undreamt/MODEL_PREFIX.it9000.src2trg.pth -i /content/en_test.txt -o /content/reference.txt
# Out:
# /content/drive/My Drive/project_codes/undreamt/undreamt/undreamt/translator.py:59: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   varids = self.device(Variable(torch.LongTensor(ids), requires_grad=False, volatile=not train))
# /content/drive/My Drive/project_codes/undreamt/undreamt/undreamt/attention.py:45: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/Indexing.cu:963.)
#   align.data.masked_fill_(mask, -float('inf'))

# %%
#/content/drive/My\ Drive/UNdreaMT/undreamt/MODEL_PREFIX.it7.src2trg.pth
#/content/drive/My\ Drive/Datasets/HIN-KAN/cleaned/Models/Semi2/Ayush_semi2.final.src2trg.pth
